# %%
getwd()
# Out:
# [1] "C:/Users/PC/A_Progetto1/TIMES_SERIE_BANDE/Bande"

# %%
setwd('C:/Users/PC/A_Progetto1/TIMES_SERIE_BANDE/Bande/Dati/S2B01')
#dir()

# %%
img_test<-'./S2coas_20170421.tif'
img_test1<-'./S2coas_20170421.tif'

# %%
img_test
# Out:
# [1] "./S2coas_20170421.tif"

# %%
.libPaths()
lib_path <- 'C:/Users/PC/AppData/Local/R/win-library/4.2'
# Out:
# [1] "C:/Users/PC/AppData/Local/R/win-library/4.2"
# [2] "C:/Program Files/R/R-4.2.2/library"

# %%
install.packages('tiff', lib = lib_path)
# Out:
# Warning message:
# "non è possibile accedere all'indice per il repository https://cran.r-project.org/src/contrib:
#   non è possibile aprire URL 'https://cran.r-project.org/src/contrib/PACKAGES'"
# Warning message:
# "il pacchetto 'tiff' non è disponibile for this version of R
#
# Una versione di questo pacchetto per la tua versione di R potrebbe essere disponibile altrove,
# si veda su
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages"
# Warning message:
# "non è possibile accedere all'indice per il repository https://cran.r-project.org/bin/windows/contrib/4.2:
#   non è possibile aprire URL 'https://cran.r-project.org/bin/windows/contrib/4.2/PACKAGES'"

# %%
#LETTURA
#readTIFF(source, native = FALSE, all = FALSE, convert = FALSE,info = FALSE, indexed = FALSE, as.is = FALSE,payload = TRUE

library(tiff)
img_test<-readTIFF(img_test)

#https://stackoverflow.com/questions/27608124/imagemagick-how-to-get-rid-of-tiffwarnings-768-message-about-unknown-field-wh
#ERRORE------>CAMPO SCONOSCIUTO METRE SI ELABORA IMMAGINE TIF, PERCHE??
# Out:
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 33550 (0x830e) encountered"
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 33922 (0x8482) encountered"
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 34735 (0x87af) encountered"
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 34737 (0x87b1) encountered"
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 42112 (0xa480) encountered"
# Warning message in readTIFF(img_test):
# "TIFFReadDirectory: Unknown field with tag 42113 (0xa481) encountered"

# %%
img_test
# Out:
#       [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
#  [1,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [2,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [3,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [4,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [5,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [6,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [7,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [8,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
#  [9,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
# [10,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
# [11,] -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38 -3.4e+38
# ...

# %%
typeof(img_test)
# Out:
# [1] "double"
